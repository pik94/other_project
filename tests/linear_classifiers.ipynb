# %%
import mglearn
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import "Make forge" dataset

# %% [markdown]
# #
